# %%
print("Loading Libraries...")
import os, sys
import csv
import platform
import numpy as np
import pandas as pd
import dask.dataframe as dd
import scipy
import sklearn
import matplotlib.pyplot as plt
import flask
import math
import scipy.interpolate as scin
from matplotlib import cm
from matplotlib.ticker import LinearLocator
from matplotlib.ticker import MaxNLocator
from matplotlib.colors import ListedColormap
from matplotlib.colors import BoundaryNorm
from matplotlib.colors import LogNorm
from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import griddata
from sklearn import neighbors, datasets
print("Loaded Libraries...")
# Out:
# Loading Libraries...
# Loaded Libraries...

# %%
print("Starting code...")
# Out:
# Starting code...

# %%
print("Loading directories..")
path_data = 'D:/01_Dokumenty/01_PUT/01_DOKTORAT/13_PLGRID/noise-data/int-01'
path_post = 'D:/01_Dokumenty/01_PUT/01_DOKTORAT/13_PLGRID/noise-data/int-01/post'
path_acu = 'D:/01_Dokumenty/01_PUT/01_DOKTORAT/13_PLGRID/noise-data/int-01/post/acu'
path_plots = 'D:/01_Dokumenty/01_PUT/01_DOKTORAT/13_PLGRID/noise-data/int-01/post/plots' #ścieżka do katalogu z interesującymi nas plikami
print("Loaded directories...")
# Out:
# Loading directories..
# Loaded directories...

# %%
print("Loading batch data...")
os.chdir(path_data)
batch_data = dd.read_csv('int-01-*.dat', delimiter=r"\s+", decimal='.')
print("Batch data done...")
# Out:
# Loading batch data...
# Batch data done...

# %%
print("Calculating batch averages...")
averages = pd.DataFrame(batch_data.groupby('nodenumber').mean().compute())
print("Batch averages done...")
# Out:
# Calculating batch averages...
# Batch averages done...

# %%
print("Generating node coordinates...")
avg_static_p = pd.DataFrame({'pressure': averages['pressure']})
node_coords = pd.DataFrame({
    'x-coordinate': averages['x-coordinate'],
    'y-coordinate': averages['y-coordinate'],
    'z-coordinate': averages['z-coordinate']
})
print("Node coordinates done...")
# Out:
# Generating node coordinates...
# Node coordinates done...

# %%
del(batch_data)
print("Batch data deleted...")
# Out:
# Batch data deleted...

# %%
print("Listing files...")
filelist = os.listdir(path_data)
# Out:
# Listing files...

# %%
print("Starting noise analysis loop...")
for file in filelist:
    os.chdir(path_data)
    timestep = str(os.path.basename(str(file)))[7:-4]
    #time_static_p = pd.DataFrame(pd.read_csv(file, sep='/s+', header=0, usecols=["nodenumber", "pressure"], skiprows=0, decimal='.')).set_index('nodenumber')
    time_static_p = pd.DataFrame(pd.read_csv(file, delimiter=r"\s+", header=0, usecols=["nodenumber", "pressure"], skiprows=0, decimal='.')).set_index('nodenumber')
    acoustic_p = time_static_p.subtract(avg_static_p, fill_value=None)
    db = acoustic_p.apply(lambda x: 20 * np.log10(np.abs(x)/0.00002), axis=1)
    acoustic_data = pd.concat([node_coords, acoustic_p, db], axis=1)
    acoustic_data.columns = ['x-coordinate', 'y-coordinate', 'z-coordinate', 'sound-pressure', 'db-level']
    os.chdir(path_acu)
    acoustic_data.to_csv(str('int-01_acu_' + str(timestep) + '.dat'), sep=',')
    print(str('int-01_acu_' + str(timestep) + '.dat done...'))
print("Exiting noise analysis loop...")
# Out:
# Starting noise analysis loop...
# int-01_acu_0001.dat done...
# int-01_acu_0002.dat done...
# int-01_acu_0003.dat done...
# int-01_acu_0004.dat done...
# int-01_acu_0005.dat done...
# int-01_acu_0006.dat done...
# int-01_acu_0007.dat done...

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-efbe430ee0c1> in <module>()
#       6     time_static_p = pd.DataFrame(pd.read_csv(file, delimiter=r"\s+", header=0, usecols=["nodenumber", "pressure"], skiprows=0, decimal='.')).set_index('nodenumber')
#       7     acoustic_p = time_static_p.subtract(avg_static_p, fill_value=None)
# ----> 8     db = acoustic_p.apply(lambda x: 20 * np.log10(np.abs(x)/0.00002), axis=1)
#       9     acoustic_data = pd.concat([node_coords, acoustic_p, db], axis=1)
#      10     acoustic_data.columns = ['x-coordinate', 'y-coordinate', 'z-coordinate', 'sound-pressure', 'db-level']
#
# C:\Users\Jedrzej\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# C:\Users\Jedrzej\Anaconda3\lib\site-packages\pandas\core\frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4373                 index = None
#    4374
# -> 4375             result = self._constructor(data=results, index=index)
#    4376             result.columns = res_index
#    4377
#
# C:\Users\Jedrzej\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     273                                  dtype=dtype, copy=copy)
#     274         elif isinstance(data, dict):
# --> 275             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     276         elif isinstance(data, ma.MaskedArray):
#     277             import numpy.ma.mrecords as mrecords
#
# C:\Users\Jedrzej\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     409             arrays = [data[k] for k in keys]
#     410
# --> 411         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     412
#     413     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# C:\Users\Jedrzej\Anaconda3\lib\site-packages\pandas\core\frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5504     axes = [_ensure_index(columns), _ensure_index(index)]
#    5505
# -> 5506     return create_block_manager_from_arrays(arrays, arr_names, axes)
#    5507
#    5508
#
# C:\Users\Jedrzej\Anaconda3\lib\site-packages\pandas\core\internals.py in create_block_manager_from_arrays(arrays, names, axes)
#    4307
#    4308     try:
# -> 4309         blocks = form_blocks(arrays, names, axes)
#    4310         mgr = BlockManager(blocks, axes)
#    4311         mgr._consolidate_inplace()
#
# C:\Users\Jedrzej\Anaconda3\lib\site-packages\pandas\core\internals.py in form_blocks(arrays, names, axes)
#    4371     blocks = []
#    4372     if len(float_items):
# -> 4373         float_blocks = _multi_blockify(float_items)
#    4374         blocks.extend(float_blocks)
#    4375
#
# C:\Users\Jedrzej\Anaconda3\lib\site-packages\pandas\core\internals.py in _multi_blockify(tuples, dtype)
#    4448     for dtype, tup_block in grouper:
#    4449
# -> 4450         values, placement = _stack_arrays(list(tup_block), dtype)
#    4451
#    4452         block = make_block(values, placement=placement)
#
# C:\Users\Jedrzej\Anaconda3\lib\site-packages\pandas\core\internals.py in _stack_arrays(tuples, dtype)
#    4493     stacked = np.empty(shape, dtype=dtype)
#    4494     for i, arr in enumerate(arrays):
# -> 4495         stacked[i] = _asarray_compat(arr)
#    4496
#    4497     return stacked, placement
#
# KeyboardInterrupt:

# %%
print("Loading batch acoustic data...")
os.chdir(path_acu)
batch_data = dd.read_csv('int-01*.dat', sep=',', decimal='.')
print("Batch data done...")
# Out:
# Loading batch acoustic data...
# Batch data done...

# %%
print("Calculating batch minimums...")
minima = pd.DataFrame(batch_data.groupby('nodenumber').min().compute())
print("Batch minimums done...")
# Out:
# Calculating batch minimums...
# Batch minimums done...

# %%
min_spl=np.amin(minima['sound-pressure'])
min_dbl=np.amin(minima['db-level'])
print(min_spl)
print(min_dbl)
# Out:
# -14360.1998444
# 17.629099526

# %%
print("Calculating batch maximums...")
maxima = pd.DataFrame(batch_data.groupby('nodenumber').max().compute())
print("Batch maximums done...")
# Out:
# Calculating batch maximums...
# Batch maximums done...

# %%
max_spl=np.amax(maxima['sound-pressure'])
max_dbl=np.amax(maxima['db-level'])
print(max_spl)
print(max_dbl)
# Out:
# 11846.6950986
# 177.122609763

# %%
print("Calculating batch std dev...")
maxima = pd.DataFrame(batch_data.groupby('nodenumber').max().compute())
print("Batch std dev done...")

# %%
print("Starting plotting loop...")
splv = np.linspace(min_spl, max_spl, 100, endpoint=False)
dbv = np.linspace(min_dbl, max_dbl, num=100, endpoint=False)
os.chdir(path_acu)
filelist = os.listdir(path_acu)
for file in filelist:
    timestep = str(os.path.basename(str(file)))[11:-4]
    os.chdir(path_acu)
    acu = pd.read_csv(file, sep=',', decimal='.', header=0)
    x = acu['x-coordinate']
    y = acu['y-coordinate']
    z = acu['z-coordinate']
    spl = acu['sound-pressure']
    dbl = acu['db-level']
    fig, (ax0, ax1) = plt.subplots(nrows=2, figsize=(10, 10), dpi=300)
    spl_plot = ax0.tricontourf(z, x, spl, splv, cmap=plt.cm.bone)
    fig.colorbar(spl_plot, ax=ax0)
    ax0.set_title(str('Sound pressure. Int-01. Time: ' + str(timestep)))
    dbl_plot = ax1.tricontourf(z, x, dbl, dbv, cmap=plt.cm.jet)
    fig.colorbar(dbl_plot, ax=ax1)
    ax1.set_title(str('dB level. Int-01. Time: ' + str(timestep)))
    os.chdir(path_plots)
    plt.savefig(str('int-01_acu_t_' + str(timestep) + '.png'))
    plt.close()
    print(str('int-01_acu_t_' + str(timestep) + '.png done...'))
print("Exiting plotting loop...")
# Out:
# Starting plotting loop...
# int-01_acu_t_0001.png done...
# int-01_acu_t_0002.png done...
# int-01_acu_t_0003.png done...
# int-01_acu_t_0004.png done...
# int-01_acu_t_0005.png done...
# int-01_acu_t_0006.png done...
# int-01_acu_t_0007.png done...
# int-01_acu_t_0008.png done...
# int-01_acu_t_0009.png done...
# int-01_acu_t_0010.png done...
# int-01_acu_t_0011.png done...
# int-01_acu_t_0012.png done...
# int-01_acu_t_0013.png done...
# int-01_acu_t_0014.png done...
# int-01_acu_t_0015.png done...
# int-01_acu_t_0016.png done...
# int-01_acu_t_0017.png done...
# int-01_acu_t_0018.png done...
# int-01_acu_t_0019.png done...
# int-01_acu_t_0020.png done...
# int-01_acu_t_0021.png done...
# int-01_acu_t_0022.png done...
# int-01_acu_t_0023.png done...
# int-01_acu_t_0024.png done...
# int-01_acu_t_0025.png done...
# int-01_acu_t_0026.png done...
# int-01_acu_t_0027.png done...
# int-01_acu_t_0028.png done...
# int-01_acu_t_0029.png done...
# int-01_acu_t_0030.png done...
# int-01_acu_t_0031.png done...
# int-01_acu_t_0032.png done...
# int-01_acu_t_0033.png done...
# int-01_acu_t_0034.png done...
# int-01_acu_t_0035.png done...
# int-01_acu_t_0036.png done...
# int-01_acu_t_0037.png done...
# int-01_acu_t_0038.png done...
# int-01_acu_t_0039.png done...
# int-01_acu_t_0040.png done...
# int-01_acu_t_0041.png done...
# int-01_acu_t_0042.png done...
# int-01_acu_t_0043.png done...
# int-01_acu_t_0044.png done...
# int-01_acu_t_0045.png done...
# int-01_acu_t_0046.png done...
# int-01_acu_t_0047.png done...
# int-01_acu_t_0048.png done...
# int-01_acu_t_0049.png done...
# int-01_acu_t_0050.png done...
# int-01_acu_t_0051.png done...
# int-01_acu_t_0052.png done...
# int-01_acu_t_0053.png done...
# int-01_acu_t_0054.png done...
# int-01_acu_t_0055.png done...
# int-01_acu_t_0056.png done...
# int-01_acu_t_0057.png done...
# int-01_acu_t_0058.png done...
# int-01_acu_t_0059.png done...
# int-01_acu_t_0060.png done...
# int-01_acu_t_0061.png done...
# int-01_acu_t_0062.png done...
# int-01_acu_t_0063.png done...
# int-01_acu_t_0064.png done...
# int-01_acu_t_0065.png done...
# int-01_acu_t_0066.png done...
# int-01_acu_t_0067.png done...
# int-01_acu_t_0068.png done...
# int-01_acu_t_0069.png done...
# int-01_acu_t_0070.png done...
# int-01_acu_t_0071.png done...
# int-01_acu_t_0072.png done...
# int-01_acu_t_0073.png done...
# int-01_acu_t_0074.png done...
# int-01_acu_t_0075.png done...
# int-01_acu_t_0076.png done...
# int-01_acu_t_0077.png done...
# int-01_acu_t_0078.png done...
# int-01_acu_t_0079.png done...
# int-01_acu_t_0080.png done...
# int-01_acu_t_0081.png done...
# int-01_acu_t_0082.png done...
# int-01_acu_t_0083.png done...
# int-01_acu_t_0084.png done...
# int-01_acu_t_0085.png done...
# int-01_acu_t_0086.png done...
# int-01_acu_t_0087.png done...
# int-01_acu_t_0088.png done...
# int-01_acu_t_0089.png done...
# int-01_acu_t_0090.png done...
# int-01_acu_t_0091.png done...
# int-01_acu_t_0092.png done...
# int-01_acu_t_0093.png done...
# int-01_acu_t_0094.png done...
# int-01_acu_t_0095.png done...
# int-01_acu_t_0096.png done...
# int-01_acu_t_0097.png done...
# int-01_acu_t_0098.png done...
# int-01_acu_t_0099.png done...
# int-01_acu_t_0100.png done...
# int-01_acu_t_0101.png done...
# int-01_acu_t_0102.png done...
# int-01_acu_t_0103.png done...
# int-01_acu_t_0104.png done...
# int-01_acu_t_0105.png done...
# int-01_acu_t_0106.png done...
# int-01_acu_t_0107.png done...
# int-01_acu_t_0108.png done...
# int-01_acu_t_0109.png done...
# int-01_acu_t_0110.png done...
# int-01_acu_t_0111.png done...
# int-01_acu_t_0112.png done...
# int-01_acu_t_0113.png done...
# int-01_acu_t_0114.png done...
# int-01_acu_t_0115.png done...
# int-01_acu_t_0116.png done...
# int-01_acu_t_0117.png done...
# int-01_acu_t_0118.png done...
# int-01_acu_t_0119.png done...
# int-01_acu_t_0120.png done...
# int-01_acu_t_0121.png done...
# int-01_acu_t_0122.png done...
# int-01_acu_t_0123.png done...
# int-01_acu_t_0124.png done...
# int-01_acu_t_0125.png done...
# int-01_acu_t_0126.png done...
# int-01_acu_t_0127.png done...
# int-01_acu_t_0128.png done...
# int-01_acu_t_0129.png done...
# int-01_acu_t_0130.png done...
# int-01_acu_t_0131.png done...
# int-01_acu_t_0132.png done...
# int-01_acu_t_0133.png done...
# int-01_acu_t_0134.png done...
# int-01_acu_t_0135.png done...
# int-01_acu_t_0136.png done...
# int-01_acu_t_0137.png done...
# int-01_acu_t_0138.png done...
# int-01_acu_t_0139.png done...
# int-01_acu_t_0140.png done...
# int-01_acu_t_0141.png done...
# int-01_acu_t_0142.png done...
# int-01_acu_t_0143.png done...
# int-01_acu_t_0144.png done...
# int-01_acu_t_0145.png done...
# int-01_acu_t_0146.png done...
# int-01_acu_t_0147.png done...
# int-01_acu_t_0148.png done...
# int-01_acu_t_0149.png done...
# int-01_acu_t_0150.png done...
# int-01_acu_t_0151.png done...
# int-01_acu_t_0152.png done...
# int-01_acu_t_0153.png done...
# int-01_acu_t_0154.png done...
# int-01_acu_t_0155.png done...
# int-01_acu_t_0156.png done...
# int-01_acu_t_0157.png done...
# int-01_acu_t_0158.png done...
# int-01_acu_t_0159.png done...
# int-01_acu_t_0160.png done...
# int-01_acu_t_0161.png done...
# int-01_acu_t_0162.png done...
# int-01_acu_t_0163.png done...
# int-01_acu_t_0164.png done...
# int-01_acu_t_0165.png done...
# int-01_acu_t_0166.png done...
# int-01_acu_t_0167.png done...
# int-01_acu_t_0168.png done...
# int-01_acu_t_0169.png done...
# int-01_acu_t_0170.png done...
# int-01_acu_t_0171.png done...
# int-01_acu_t_0172.png done...
# int-01_acu_t_0173.png done...
# int-01_acu_t_0174.png done...
# int-01_acu_t_0175.png done...
# int-01_acu_t_0176.png done...
# int-01_acu_t_0177.png done...
# int-01_acu_t_0178.png done...
# int-01_acu_t_0179.png done...
# int-01_acu_t_0180.png done...
# int-01_acu_t_0181.png done...
# int-01_acu_t_0182.png done...
# int-01_acu_t_0183.png done...
# int-01_acu_t_0184.png done...
# int-01_acu_t_0185.png done...
# int-01_acu_t_0186.png done...
# int-01_acu_t_0187.png done...
# int-01_acu_t_0188.png done...
# int-01_acu_t_0189.png done...
# int-01_acu_t_0190.png done...
# int-01_acu_t_0191.png done...
# int-01_acu_t_0192.png done...
# int-01_acu_t_0193.png done...
# int-01_acu_t_0194.png done...
# int-01_acu_t_0195.png done...
# int-01_acu_t_0196.png done...
# int-01_acu_t_0197.png done...
# int-01_acu_t_0198.png done...
# int-01_acu_t_0199.png done...
# int-01_acu_t_0200.png done...
# int-01_acu_t_0201.png done...
# int-01_acu_t_0202.png done...
# int-01_acu_t_0203.png done...
# int-01_acu_t_0204.png done...
# int-01_acu_t_0205.png done...
# int-01_acu_t_0206.png done...
# int-01_acu_t_0207.png done...
# int-01_acu_t_0208.png done...
# int-01_acu_t_0209.png done...
# int-01_acu_t_0210.png done...
# int-01_acu_t_0211.png done...
# int-01_acu_t_0212.png done...
# int-01_acu_t_0213.png done...
# int-01_acu_t_0214.png done...
# int-01_acu_t_0215.png done...
# int-01_acu_t_0216.png done...
# int-01_acu_t_0217.png done...
# int-01_acu_t_0218.png done...
# int-01_acu_t_0219.png done...
# int-01_acu_t_0220.png done...
# int-01_acu_t_0221.png done...
# int-01_acu_t_0222.png done...
# int-01_acu_t_0223.png done...
# int-01_acu_t_0224.png done...
# int-01_acu_t_0225.png done...
# int-01_acu_t_0226.png done...
# int-01_acu_t_0227.png done...
# int-01_acu_t_0228.png done...
# int-01_acu_t_0229.png done...
# int-01_acu_t_0230.png done...
# int-01_acu_t_0231.png done...
# int-01_acu_t_0232.png done...
# int-01_acu_t_0233.png done...
# int-01_acu_t_0234.png done...
# int-01_acu_t_0235.png done...
# int-01_acu_t_0236.png done...
# int-01_acu_t_0237.png done...
# int-01_acu_t_0238.png done...
# int-01_acu_t_0239.png done...
# int-01_acu_t_0240.png done...
# int-01_acu_t_0241.png done...
# int-01_acu_t_0242.png done...
# int-01_acu_t_0243.png done...
# int-01_acu_t_0244.png done...
# int-01_acu_t_0245.png done...
# int-01_acu_t_0246.png done...
# int-01_acu_t_0247.png done...
# int-01_acu_t_0248.png done...
# int-01_acu_t_0249.png done...
# int-01_acu_t_0250.png done...
# int-01_acu_t_0251.png done...
# int-01_acu_t_0252.png done...
# int-01_acu_t_0253.png done...
# int-01_acu_t_0254.png done...
# int-01_acu_t_0255.png done...
# int-01_acu_t_0256.png done...
# int-01_acu_t_0257.png done...
# int-01_acu_t_0258.png done...
# int-01_acu_t_0259.png done...
# int-01_acu_t_0260.png done...
# int-01_acu_t_0261.png done...
# int-01_acu_t_0262.png done...
# int-01_acu_t_0263.png done...
# int-01_acu_t_0264.png done...
# int-01_acu_t_0265.png done...
# int-01_acu_t_0266.png done...
# int-01_acu_t_0267.png done...
# int-01_acu_t_0268.png done...
# int-01_acu_t_0269.png done...
# int-01_acu_t_0270.png done...
# int-01_acu_t_0271.png done...
# int-01_acu_t_0272.png done...
# int-01_acu_t_0273.png done...
# int-01_acu_t_0274.png done...
# int-01_acu_t_0275.png done...
# int-01_acu_t_0276.png done...
# int-01_acu_t_0277.png done...
# int-01_acu_t_0278.png done...
# int-01_acu_t_0279.png done...
# int-01_acu_t_0280.png done...
# int-01_acu_t_0281.png done...
# int-01_acu_t_0282.png done...
# int-01_acu_t_0283.png done...
# int-01_acu_t_0284.png done...
# int-01_acu_t_0285.png done...
# int-01_acu_t_0286.png done...
# int-01_acu_t_0287.png done...
# int-01_acu_t_0288.png done...
# int-01_acu_t_0289.png done...
# int-01_acu_t_0290.png done...
# int-01_acu_t_0291.png done...
# int-01_acu_t_0292.png done...
# int-01_acu_t_0293.png done...
# int-01_acu_t_0294.png done...
# int-01_acu_t_0295.png done...
# int-01_acu_t_0296.png done...
# int-01_acu_t_0297.png done...
# int-01_acu_t_0298.png done...
# int-01_acu_t_0299.png done...
# int-01_acu_t_0300.png done...
# int-01_acu_t_0301.png done...
# int-01_acu_t_0302.png done...
# int-01_acu_t_0303.png done...
# int-01_acu_t_0304.png done...
# int-01_acu_t_0305.png done...
# int-01_acu_t_0306.png done...
# int-01_acu_t_0307.png done...
# int-01_acu_t_0308.png done...
# int-01_acu_t_0309.png done...
# int-01_acu_t_0310.png done...
# int-01_acu_t_0311.png done...
# int-01_acu_t_0312.png done...
# int-01_acu_t_0313.png done...
# int-01_acu_t_0314.png done...
# int-01_acu_t_0315.png done...
# int-01_acu_t_0316.png done...
# int-01_acu_t_0317.png done...
# int-01_acu_t_0318.png done...
# int-01_acu_t_0319.png done...
# int-01_acu_t_0320.png done...
# int-01_acu_t_0321.png done...
# int-01_acu_t_0322.png done...
# int-01_acu_t_0323.png done...
# int-01_acu_t_0324.png done...
# int-01_acu_t_0325.png done...
# int-01_acu_t_0326.png done...
# int-01_acu_t_0327.png done...
# int-01_acu_t_0328.png done...
# int-01_acu_t_0329.png done...
# int-01_acu_t_0330.png done...
# int-01_acu_t_0331.png done...
# int-01_acu_t_0332.png done...
# int-01_acu_t_0333.png done...
# int-01_acu_t_0334.png done...
# int-01_acu_t_0335.png done...
# int-01_acu_t_0336.png done...
# int-01_acu_t_0337.png done...
# int-01_acu_t_0338.png done...
# int-01_acu_t_0339.png done...
# int-01_acu_t_0340.png done...
# int-01_acu_t_0341.png done...
# int-01_acu_t_0342.png done...
# int-01_acu_t_0343.png done...
# int-01_acu_t_0344.png done...
# int-01_acu_t_0345.png done...
# int-01_acu_t_0346.png done...
# int-01_acu_t_0347.png done...
# int-01_acu_t_0348.png done...
# int-01_acu_t_0349.png done...
# int-01_acu_t_0350.png done...
# int-01_acu_t_0351.png done...
# int-01_acu_t_0352.png done...
# int-01_acu_t_0353.png done...
# int-01_acu_t_0354.png done...
# int-01_acu_t_0355.png done...
# int-01_acu_t_0356.png done...
# int-01_acu_t_0357.png done...
# int-01_acu_t_0358.png done...
# int-01_acu_t_0359.png done...
# int-01_acu_t_0360.png done...
# int-01_acu_t_0361.png done...
# int-01_acu_t_0362.png done...
# int-01_acu_t_0363.png done...
# int-01_acu_t_0364.png done...
# int-01_acu_t_0365.png done...
# int-01_acu_t_0366.png done...
# int-01_acu_t_0367.png done...
# int-01_acu_t_0368.png done...
# int-01_acu_t_0369.png done...
# int-01_acu_t_0370.png done...
# int-01_acu_t_0371.png done...
# int-01_acu_t_0372.png done...
# int-01_acu_t_0373.png done...
# int-01_acu_t_0374.png done...
# int-01_acu_t_0375.png done...
# int-01_acu_t_0376.png done...
# int-01_acu_t_0377.png done...
# int-01_acu_t_0378.png done...
# int-01_acu_t_0379.png done...
# int-01_acu_t_0380.png done...
# int-01_acu_t_0381.png done...
# int-01_acu_t_0382.png done...
# int-01_acu_t_0383.png done...
# int-01_acu_t_0384.png done...
# int-01_acu_t_0385.png done...
# int-01_acu_t_0386.png done...
# int-01_acu_t_0387.png done...
# int-01_acu_t_0388.png done...
# int-01_acu_t_0389.png done...
# int-01_acu_t_0390.png done...
# int-01_acu_t_0391.png done...
# int-01_acu_t_0392.png done...
# int-01_acu_t_0393.png done...
# int-01_acu_t_0394.png done...
# int-01_acu_t_0395.png done...
# int-01_acu_t_0396.png done...
# int-01_acu_t_0397.png done...
# int-01_acu_t_0398.png done...
# int-01_acu_t_0399.png done...
# int-01_acu_t_0400.png done...
# int-01_acu_t_0401.png done...
# int-01_acu_t_0402.png done...
# int-01_acu_t_0403.png done...
# int-01_acu_t_0404.png done...
# int-01_acu_t_0405.png done...
# int-01_acu_t_0406.png done...
# int-01_acu_t_0407.png done...
# int-01_acu_t_0408.png done...
# int-01_acu_t_0409.png done...
# int-01_acu_t_0410.png done...
# int-01_acu_t_0411.png done...
# int-01_acu_t_0412.png done...
# int-01_acu_t_0413.png done...
# int-01_acu_t_0414.png done...
# int-01_acu_t_0415.png done...
# int-01_acu_t_0416.png done...
# int-01_acu_t_0417.png done...
# int-01_acu_t_0418.png done...
# int-01_acu_t_0419.png done...
# int-01_acu_t_0420.png done...
# int-01_acu_t_0421.png done...
# int-01_acu_t_0422.png done...
# int-01_acu_t_0423.png done...
# int-01_acu_t_0424.png done...
# int-01_acu_t_0425.png done...
# int-01_acu_t_0426.png done...
# int-01_acu_t_0427.png done...
# int-01_acu_t_0428.png done...
# int-01_acu_t_0429.png done...
# int-01_acu_t_0430.png done...
# int-01_acu_t_0431.png done...
# int-01_acu_t_0432.png done...
# int-01_acu_t_0433.png done...
# int-01_acu_t_0434.png done...
# int-01_acu_t_0435.png done...
# int-01_acu_t_0436.png done...
# int-01_acu_t_0437.png done...
# int-01_acu_t_0438.png done...
# int-01_acu_t_0439.png done...
# int-01_acu_t_0440.png done...
# int-01_acu_t_0441.png done...
# int-01_acu_t_0442.png done...
# int-01_acu_t_0443.png done...
# int-01_acu_t_0444.png done...
# int-01_acu_t_0445.png done...
# int-01_acu_t_0446.png done...
# int-01_acu_t_0447.png done...
# int-01_acu_t_0448.png done...
# int-01_acu_t_0449.png done...
# int-01_acu_t_0450.png done...
# int-01_acu_t_0451.png done...
# int-01_acu_t_0452.png done...
# int-01_acu_t_0453.png done...
# int-01_acu_t_0454.png done...
# int-01_acu_t_0455.png done...
# int-01_acu_t_0456.png done...
# int-01_acu_t_0457.png done...
# int-01_acu_t_0458.png done...
# int-01_acu_t_0459.png done...
# int-01_acu_t_0460.png done...
# int-01_acu_t_0461.png done...
# int-01_acu_t_0462.png done...
# int-01_acu_t_0463.png done...
# int-01_acu_t_0464.png done...
# int-01_acu_t_0465.png done...
# int-01_acu_t_0466.png done...
# int-01_acu_t_0467.png done...
# int-01_acu_t_0468.png done...
# int-01_acu_t_0469.png done...
# int-01_acu_t_0470.png done...
# int-01_acu_t_0471.png done...
# int-01_acu_t_0472.png done...
# int-01_acu_t_0473.png done...
# int-01_acu_t_0474.png done...
# int-01_acu_t_0475.png done...
# int-01_acu_t_0476.png done...
# int-01_acu_t_0477.png done...
# int-01_acu_t_0478.png done...
# int-01_acu_t_0479.png done...
# int-01_acu_t_0480.png done...
# int-01_acu_t_0481.png done...
# int-01_acu_t_0482.png done...
# int-01_acu_t_0483.png done...
# int-01_acu_t_0484.png done...
# int-01_acu_t_0485.png done...
# int-01_acu_t_0486.png done...
# int-01_acu_t_0487.png done...
# int-01_acu_t_0488.png done...
# int-01_acu_t_0489.png done...
# int-01_acu_t_0490.png done...
# int-01_acu_t_0491.png done...
# int-01_acu_t_0492.png done...
# int-01_acu_t_0493.png done...
# int-01_acu_t_0494.png done...
# int-01_acu_t_0495.png done...
# int-01_acu_t_0496.png done...
# int-01_acu_t_0497.png done...
# int-01_acu_t_0498.png done...
# int-01_acu_t_0499.png done...
# int-01_acu_t_0500.png done...
# int-01_acu_t_0501.png done...
# int-01_acu_t_0502.png done...
# int-01_acu_t_0503.png done...
# int-01_acu_t_0504.png done...
# int-01_acu_t_0505.png done...
# int-01_acu_t_0506.png done...
# int-01_acu_t_0507.png done...
# int-01_acu_t_0508.png done...
# int-01_acu_t_0509.png done...
# int-01_acu_t_0510.png done...
# int-01_acu_t_0511.png done...
# int-01_acu_t_0512.png done...
# int-01_acu_t_0513.png done...
# int-01_acu_t_0514.png done...
# int-01_acu_t_0515.png done...
# int-01_acu_t_0516.png done...
# int-01_acu_t_0517.png done...
# int-01_acu_t_0518.png done...
# int-01_acu_t_0519.png done...
# int-01_acu_t_0520.png done...
# int-01_acu_t_0521.png done...
# int-01_acu_t_0522.png done...
# int-01_acu_t_0523.png done...
# int-01_acu_t_0524.png done...
# int-01_acu_t_0525.png done...
# int-01_acu_t_0526.png done...
# int-01_acu_t_0527.png done...
# int-01_acu_t_0528.png done...
# int-01_acu_t_0529.png done...
# int-01_acu_t_0530.png done...
# int-01_acu_t_0531.png done...
# int-01_acu_t_0532.png done...
# int-01_acu_t_0533.png done...
# int-01_acu_t_0534.png done...
# int-01_acu_t_0535.png done...
# int-01_acu_t_0536.png done...
# int-01_acu_t_0537.png done...
# int-01_acu_t_0538.png done...
# int-01_acu_t_0539.png done...
# int-01_acu_t_0540.png done...
# int-01_acu_t_0541.png done...
# int-01_acu_t_0542.png done...
# int-01_acu_t_0543.png done...
# int-01_acu_t_0544.png done...
# int-01_acu_t_0545.png done...
# int-01_acu_t_0546.png done...
# int-01_acu_t_0547.png done...
# int-01_acu_t_0548.png done...
# int-01_acu_t_0549.png done...
# int-01_acu_t_0550.png done...
# int-01_acu_t_0551.png done...
# int-01_acu_t_0552.png done...
# int-01_acu_t_0553.png done...
# int-01_acu_t_0554.png done...
# int-01_acu_t_0555.png done...
# int-01_acu_t_0556.png done...
# int-01_acu_t_0557.png done...
# int-01_acu_t_0558.png done...
# int-01_acu_t_0559.png done...
# int-01_acu_t_0560.png done...
# int-01_acu_t_0561.png done...
# int-01_acu_t_0562.png done...
# int-01_acu_t_0563.png done...
# int-01_acu_t_0564.png done...
# int-01_acu_t_0565.png done...
# int-01_acu_t_0566.png done...
# int-01_acu_t_0567.png done...
# int-01_acu_t_0568.png done...
# int-01_acu_t_0569.png done...
# int-01_acu_t_0570.png done...
# int-01_acu_t_0571.png done...
# int-01_acu_t_0572.png done...
# int-01_acu_t_0573.png done...
# int-01_acu_t_0574.png done...
# int-01_acu_t_0575.png done...
# int-01_acu_t_0576.png done...
# int-01_acu_t_0577.png done...
# int-01_acu_t_0578.png done...
# int-01_acu_t_0579.png done...
# int-01_acu_t_0580.png done...
# int-01_acu_t_0581.png done...
# int-01_acu_t_0582.png done...
# int-01_acu_t_0583.png done...
# int-01_acu_t_0584.png done...
# int-01_acu_t_0585.png done...
# int-01_acu_t_0586.png done...
# int-01_acu_t_0587.png done...
# int-01_acu_t_0588.png done...
# int-01_acu_t_0589.png done...
# int-01_acu_t_0590.png done...
# int-01_acu_t_0591.png done...
# int-01_acu_t_0592.png done...
# int-01_acu_t_0593.png done...
# int-01_acu_t_0594.png done...
# int-01_acu_t_0595.png done...
# int-01_acu_t_0596.png done...
# int-01_acu_t_0597.png done...
# int-01_acu_t_0598.png done...
# int-01_acu_t_0599.png done...
# int-01_acu_t_0600.png done...
# int-01_acu_t_0601.png done...
# int-01_acu_t_0602.png done...
# int-01_acu_t_0603.png done...
# int-01_acu_t_0604.png done...
# int-01_acu_t_0605.png done...
# int-01_acu_t_0606.png done...
# int-01_acu_t_0607.png done...
# int-01_acu_t_0608.png done...
# int-01_acu_t_0609.png done...
# int-01_acu_t_0610.png done...
# int-01_acu_t_0611.png done...
# int-01_acu_t_0612.png done...
# int-01_acu_t_0613.png done...
# int-01_acu_t_0614.png done...
# int-01_acu_t_0615.png done...
# int-01_acu_t_0616.png done...
# int-01_acu_t_0617.png done...
# int-01_acu_t_0618.png done...
# int-01_acu_t_0619.png done...
# int-01_acu_t_0620.png done...
# int-01_acu_t_0621.png done...
# int-01_acu_t_0622.png done...
# int-01_acu_t_0623.png done...
# int-01_acu_t_0624.png done...
# int-01_acu_t_0625.png done...
# int-01_acu_t_0626.png done...
# int-01_acu_t_0627.png done...
# int-01_acu_t_0628.png done...
# int-01_acu_t_0629.png done...
# int-01_acu_t_0630.png done...
# int-01_acu_t_0631.png done...
# int-01_acu_t_0632.png done...
# int-01_acu_t_0633.png done...
# int-01_acu_t_0634.png done...
# int-01_acu_t_0635.png done...
# int-01_acu_t_0636.png done...
# int-01_acu_t_0637.png done...
# int-01_acu_t_0638.png done...
# int-01_acu_t_0639.png done...
# int-01_acu_t_0640.png done...
# int-01_acu_t_0641.png done...
# int-01_acu_t_0642.png done...
# int-01_acu_t_0643.png done...
# int-01_acu_t_0644.png done...
# int-01_acu_t_0645.png done...
# int-01_acu_t_0646.png done...
# int-01_acu_t_0647.png done...
# int-01_acu_t_0648.png done...
# int-01_acu_t_0649.png done...
# int-01_acu_t_0650.png done...
# int-01_acu_t_0651.png done...
# int-01_acu_t_0652.png done...
# int-01_acu_t_0653.png done...
# int-01_acu_t_0654.png done...
# int-01_acu_t_0655.png done...
# int-01_acu_t_0656.png done...
# int-01_acu_t_0657.png done...
# int-01_acu_t_0658.png done...
# int-01_acu_t_0659.png done...
# int-01_acu_t_0660.png done...
# int-01_acu_t_0661.png done...
# int-01_acu_t_0662.png done...
# int-01_acu_t_0663.png done...
# int-01_acu_t_0664.png done...
# int-01_acu_t_0665.png done...
# int-01_acu_t_0666.png done...
# int-01_acu_t_0667.png done...
# int-01_acu_t_0668.png done...
# int-01_acu_t_0669.png done...
# int-01_acu_t_0670.png done...
# int-01_acu_t_0671.png done...
# int-01_acu_t_0672.png done...
# int-01_acu_t_0673.png done...
# int-01_acu_t_0674.png done...
# int-01_acu_t_0675.png done...
# int-01_acu_t_0676.png done...
# int-01_acu_t_0677.png done...
# int-01_acu_t_0678.png done...
# int-01_acu_t_0679.png done...
# int-01_acu_t_0680.png done...
# int-01_acu_t_0681.png done...
# int-01_acu_t_0682.png done...
# int-01_acu_t_0683.png done...
# Exiting plotting loop...

# %% [markdown]
# squares = batch_data**2

# %% [markdown]
# squares

# %% [markdown]
# means = squares.groupby('nodenumber').mean().compute()

# %% [markdown]
# roots = np.sqrt(means)
# roots
