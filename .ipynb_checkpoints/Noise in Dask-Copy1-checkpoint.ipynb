# %%
import os, sys
import csv
import platform
import numpy as np
import pandas as pd
import dask.dataframe as dd
import scipy
import sklearn
import matplotlib as plt
import flask
import math

# %%
path_data = 'D:/01_Dokumenty/01_PUT/01_DOKTORAT/13_PLGRID/noise-data/int-01'
path_post = 'D:/01_Dokumenty/01_PUT/01_DOKTORAT/13_PLGRID/noise-data/int-01/post'
path_acu = 'D:/01_Dokumenty/01_PUT/01_DOKTORAT/13_PLGRID/noise-data/int-01/post/acu'
path_plots = 'D:/01_Dokumenty/01_PUT/01_DOKTORAT/13_PLGRID/noise-data/int-01/post/plots' #ścieżka do katalogu z interesującymi nas plikami

# %%
os.chdir(path_data)
batch_data = dd.read_csv('int-01-*.dat',  delimiter=r"\s+", decimal='.')
averages = pd.DataFrame(batch_data.groupby('nodenumber').mean().compute())
avg_static_p = pd.DataFrame({'pressure': averages['pressure']})
node_coords = pd.DataFrame({
    'x-coordinate': averages['x-coordinate'],
    'y-coordinate': averages['y-coordinate'],
    'z-coordinate': averages['z-coordinate']
})

# %%
averages
# Out:
#             x-coordinate  y-coordinate  z-coordinate       pressure  \
# nodenumber
# 1              -0.042275      0.096415        -0.046   87797.489531
# 2              -0.041701      0.096666        -0.046   87803.144698
# 3              -0.041127      0.096918        -0.046   87808.589888
# 4              -0.040551      0.097164        -0.046   87813.215225
# 5              -0.039969      0.097397        -0.046   87816.687204
# 6              -0.039388      0.097630        -0.046   87820.246723
# 7              -0.038806      0.097863        -0.046   87822.743553
# 8              -0.038225      0.098096        -0.046   87824.560060
# 9              -0.037643      0.098329        -0.046   87826.158906
# 10             -0.037055      0.098545        -0.046   87828.251528
# 11             -0.036466      0.098759        -0.046   87830.493208
# 12             -0.035878      0.098974        -0.046   87831.866441
# 13             -0.035289      0.099188        -0.046   87832.442373
# 14             -0.034700      0.099403        -0.046   87832.558932
# 15             -0.034107      0.099606        -0.046   87832.964377
# 16             -0.033512      0.099802        -0.046   87833.505255
# 17             -0.032917      0.099998        -0.046   87833.598051
# 18             -0.032322      0.100193        -0.046   87832.734488
# 19             -0.031727      0.100389        -0.046   87831.259998
# 20             -0.031130      0.100579        -0.046   87829.800528
# 21             -0.030529      0.100756        -0.046   87828.829847
# 22             -0.029928      0.100933        -0.046   87827.819946
# 23             -0.029326      0.101110        -0.046   87826.117382
# 24             -0.028725      0.101287        -0.046   87823.944389
# 25             -0.028124      0.101464        -0.046   87821.980638
# 26             -0.027518      0.101621        -0.046   87821.114025
# 27             -0.026912      0.101779        -0.046   87820.760682
# 28             -0.026306      0.101937        -0.046   87820.026061
# 29             -0.025700      0.102095        -0.046   87819.038888
# 30             -0.025094      0.102253        -0.046   87818.317264
# ...                  ...           ...           ...            ...
# 38109           0.025439      0.131032         0.147  106032.853653
# 38110           0.024658      0.131173         0.147  106032.853653
# 38111           0.023877      0.131313         0.147  106032.853653
# 38112           0.023097      0.131453         0.147  106032.853653
# 38113           0.022316      0.131593         0.147  106032.853653
# 38114           0.021535      0.131734         0.147  106032.853653
# 38115           0.020749      0.131850         0.147  106032.853653
# 38116           0.019962      0.131966         0.147  106032.853653
# 38117           0.019175      0.132082         0.147  106032.853653
# 38118           0.018389      0.132197         0.147  106032.853653
# 38119           0.017602      0.132313         0.147  106032.853653
# 38120           0.016813      0.132411         0.147  106032.853653
# 38121           0.016023      0.132502         0.147  106032.853653
# 38122           0.015233      0.132593         0.147  106032.853653
# 38123           0.014443      0.132685         0.147  106032.853653
# 38124           0.013653      0.132776         0.147  106032.853653
# [38138 rows x 7 columns]

# %%
avg_static_p
# Out:
#                  pressure
# nodenumber
# 1            87797.489531
# 2            87803.144698
# 3            87808.589888
# 4            87813.215225
# 5            87816.687204
# 6            87820.246723
# 7            87822.743553
# 8            87824.560060
# 9            87826.158906
# 10           87828.251528
# 11           87830.493208
# 12           87831.866441
# 13           87832.442373
# 14           87832.558932
# 15           87832.964377
# 16           87833.505255
# 17           87833.598051
# 18           87832.734488
# 19           87831.259998
# 20           87829.800528
# 21           87828.829847
# 22           87827.819946
# 23           87826.117382
# 24           87823.944389
# 25           87821.980638
# 26           87821.114025
# 27           87820.760682
# 28           87820.026061
# 29           87819.038888
# 30           87818.317264
# ...                   ...
# 38109       106032.853653
# 38110       106032.853653
# 38111       106032.853653
# 38112       106032.853653
# 38113       106032.853653
# 38114       106032.853653
# 38115       106032.853653
# 38116       106032.853653
# 38117       106032.853653
# 38118       106032.853653
# 38119       106032.853653
# 38120       106032.853653
# 38121       106032.853653
# 38122       106032.853653
# 38123       106032.853653
# 38124       106032.853653
# 38125       106032.853653
# 38126       106032.853653
# 38127       106032.853653
# 38128       106032.853653
# 38129       106032.853653
# 38130       106032.853653
# 38131       106032.853653
# 38132       106032.853653
# 38133       106032.853653
# 38134       106032.853653
# 38135       106032.853653
# 38136       106032.853653
# 38137       106032.853653
# 38138       106019.206149
#
# [38138 rows x 1 columns]

# %%
node_coords
# Out:
#             x-coordinate  y-coordinate  z-coordinate
# nodenumber
# 1              -0.042275      0.096415        -0.046
# 2              -0.041701      0.096666        -0.046
# 3              -0.041127      0.096918        -0.046
# 4              -0.040551      0.097164        -0.046
# 5              -0.039969      0.097397        -0.046
# 6              -0.039388      0.097630        -0.046
# 7              -0.038806      0.097863        -0.046
# 8              -0.038225      0.098096        -0.046
# 9              -0.037643      0.098329        -0.046
# 10             -0.037055      0.098545        -0.046
# 11             -0.036466      0.098759        -0.046
# 12             -0.035878      0.098974        -0.046
# 13             -0.035289      0.099188        -0.046
# 14             -0.034700      0.099403        -0.046
# 15             -0.034107      0.099606        -0.046
# 16             -0.033512      0.099802        -0.046
# 17             -0.032917      0.099998        -0.046
# 18             -0.032322      0.100193        -0.046
# 19             -0.031727      0.100389        -0.046
# 20             -0.031130      0.100579        -0.046
# 21             -0.030529      0.100756        -0.046
# 22             -0.029928      0.100933        -0.046
# 23             -0.029326      0.101110        -0.046
# 24             -0.028725      0.101287        -0.046
# 25             -0.028124      0.101464        -0.046
# 26             -0.027518      0.101621        -0.046
# 27             -0.026912      0.101779        -0.046
# 28             -0.026306      0.101937        -0.046
# 29             -0.025700      0.102095        -0.046
# 30             -0.025094      0.102253        -0.046
# ...                  ...           ...           ...
# 38109           0.025439      0.131032         0.147
# 38110           0.024658      0.131173         0.147
# 38111           0.023877      0.131313         0.147
# 38112           0.023097      0.131453         0.147
# 38113           0.022316      0.131593         0.147
# 38114           0.021535      0.131734         0.147
# 38115           0.020749      0.131850         0.147
# 38116           0.019962      0.131966         0.147
# 38117           0.019175      0.132082         0.147
# 38118           0.018389      0.132197         0.147
# 38119           0.017602      0.132313         0.147
# 38120           0.016813      0.132411         0.147
# 38121           0.016023      0.132502         0.147
# 38122           0.015233      0.132593         0.147
# 38123           0.014443      0.132685         0.147
# 38124           0.013653      0.132776         0.147
# 38125           0.012862      0.132856         0.147
# 38126           0.012069      0.132922         0.147
# 38127           0.011277      0.132988         0.147
# 38128           0.010484      0.133054         0.147
# 38129           0.009692      0.133120         0.147
# 38130           0.008899      0.133184         0.147
# 38131           0.008105      0.133225         0.147
# 38132           0.007311      0.133266         0.147
# 38133           0.006517      0.133306         0.147
# 38134           0.005722      0.133347         0.147
# 38135           0.004928      0.133388         0.147
# 38136           0.004133      0.133411         0.147
# 38137           0.003338      0.133426         0.147
# 38138           0.002543      0.133441         0.147
#
# [38138 rows x 3 columns]

# %%
del(batch_data)

# %%
filelist = os.listdir(path_data)

# %%
for file in filelist:
    os.chdir(path_data)
    timestep = str(os.path.basename(str(file)))[7:-4]
    time_static_p = pd.DataFrame(pd.read_csv(file, sep='\s+', header=0, usecols=["nodenumber", "pressure"], skiprows=0, decimal='.')).set_index('nodenumber')
    acoustic_p = time_static_p.subtract(avg_static_p, fill_value=None)
    db = acoustic_p.apply(lambda x: 20 * np.log10(np.abs(x)/0.00002), axis=1)
    db.columns = ['db-level']
    acoustic_data = pd.concat([node_coords, acoustic_p, db], axis=1)
    os.chdir(path_acu)
    acoustic_data.to_csv(str('asdp_acu_p_' + str(timestep) + '.dat'), sep=',')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-642de10de8c9> in <module>()
#       4     time_static_p = pd.DataFrame(pd.read_csv(file, sep='\s+', header=0, usecols=["nodenumber", "pressure"], skiprows=0, decimal='.')).set_index('nodenumber')
#       5     acoustic_p = time_static_p.subtract(avg_static_p, fill_value=None)
# ----> 6     db = acoustic_p.apply(lambda x: 20 * np.log10(np.abs(x)/0.00002), axis=1)
#       7     db.columns = ['db-level']
#       8     acoustic_data = pd.concat([node_coords, acoustic_p, db], axis=1)
#
# C:\Users\Jedrzej\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# C:\Users\Jedrzej\Anaconda3\lib\site-packages\pandas\core\frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4356             try:
#    4357                 for i, v in enumerate(series_gen):
# -> 4358                     results[i] = func(v)
#    4359                     keys.append(v.name)
#    4360             except Exception as e:
#
# <ipython-input-11-642de10de8c9> in <lambda>(x)
#       4     time_static_p = pd.DataFrame(pd.read_csv(file, sep='\s+', header=0, usecols=["nodenumber", "pressure"], skiprows=0, decimal='.')).set_index('nodenumber')
#       5     acoustic_p = time_static_p.subtract(avg_static_p, fill_value=None)
# ----> 6     db = acoustic_p.apply(lambda x: 20 * np.log10(np.abs(x)/0.00002), axis=1)
#       7     db.columns = ['db-level']
#       8     acoustic_data = pd.concat([node_coords, acoustic_p, db], axis=1)
#
# C:\Users\Jedrzej\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(left, right, name, na_op)
#     719                 lvalues = lvalues.values
#     720
# --> 721         result = wrap_results(safe_na_op(lvalues, rvalues))
#     722         return construct_result(
#     723             left,
#
# C:\Users\Jedrzej\Anaconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#     679     def safe_na_op(lvalues, rvalues):
#     680         try:
# --> 681             with np.errstate(all='ignore'):
#     682                 return na_op(lvalues, rvalues)
#     683         except Exception:
#
# C:\Users\Jedrzej\Anaconda3\lib\site-packages\numpy\core\numeric.py in __enter__(self)
#    3062         self.kwargs = kwargs
#    3063
# -> 3064     def __enter__(self):
#    3065         self.oldstate = seterr(**self.kwargs)
#    3066         if self.call is not _Unspecified:
#
# KeyboardInterrupt:

# %% [markdown]
# squares = batch_data**2

# %% [markdown]
# squares

# %% [markdown]
# means = squares.groupby('nodenumber').mean().compute()

# %% [markdown]
# roots = np.sqrt(means)
# roots
