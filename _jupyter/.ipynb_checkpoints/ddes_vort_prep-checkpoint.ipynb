# %%
print("Loading Libraries...")
import os, sys
import platform
import pandas as pd
import dask.dataframe as dd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import cm
import multiprocessing
from itertools import product
print("Loaded Libraries...")
# Out:
# Loading Libraries...
# Loaded Libraries...

# %%
#enterprise
print("Loading directories..")
path_coords = '/media/picard/data/anaconda/JJs_PHD/15_results/coords'
path_rms = '/media/picard/data/anaconda/JJs_PHD/15_results/rms'
path_mag = '/media/picard/data/anaconda/JJs_PHD/15_results/mag'
path_rans = '/media/picard/data/anaconda/JJs_PHD/15_results/r67_valid/rans'
path_ddes = '/media/picard/data/anaconda/JJs_PHD/15_results/r67_valid/ddes'
path_flow = '/media/picard/data/anaconda/JJs_PHD/15_results/flow-data'
print("Loaded directories...")
# Out:
# Loading directories..
# Loaded directories...

# %%
print("Loading batch data...")
os.chdir(path_flow)
os.chdir('./int-01')
batch_data = dd.read_csv('*.dat', delimiter=r"\s+", decimal='.', usecols=['nodenumber', 'vorticity-mag'])
print("Batch data done...")
# Out:
# Loading batch data...
# Batch data done...

# %%
avg_vort_mag = pd.DataFrame(batch_data.groupby('nodenumber').mean().compute())
avg_vort_mag
# Out:
#             vorticity-mag
# nodenumber
# 1              147.534206
# 2              152.367683
# 3              161.163231
# 4              167.144507
# 5              170.974558
# 6              173.388605
# 7              173.451271
# 8              171.413311
# 9              167.007912
# 10             161.098048
# 11             153.460635
# 12             145.143948
# 13             136.491665
# 14             127.852680
# 15             119.643824
# 16             112.198550
# 17             106.136837
# 18             101.266839
# 19              98.011768
# 20              95.574851
# 21              94.380984
# 22              93.706717
# 23              93.293155
# 24              93.020566
# 25              91.381630
# 26              90.826275
# 27              89.518773
# 28              86.741350
# 29              82.932169
# 30              76.749558
# ...                   ...
# 38109        10834.469367
# 38110         8920.366954
# 38111         7217.642619
# ...

# %%
filelist = sorted(os.listdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-01'))
filelist
# Out:
# ['int-01-33321.dat',
#  'int-01-33331.dat',
#  'int-01-33341.dat',
#  'int-01-33351.dat',
#  'int-01-33361.dat',
#  'int-01-33371.dat',
#  'int-01-33381.dat',
#  'int-01-33391.dat',
#  'int-01-33401.dat',
#  'int-01-33411.dat',
#  'int-01-33421.dat',
#  'int-01-33431.dat',
#  'int-01-33441.dat',
#  'int-01-33451.dat',
#  'int-01-33461.dat',
#  'int-01-33471.dat',
#  'int-01-33481.dat',
#  'int-01-33491.dat',
#  'int-01-33501.dat',
#  'int-01-33511.dat',
#  'int-01-33521.dat',
#  'int-01-33531.dat',
#  'int-01-33541.dat',
#  'int-01-33551.dat',
#  'int-01-33561.dat',
#  'int-01-33571.dat',
#  'int-01-33581.dat',
#  'int-01-33591.dat',
#  'int-01-33601.dat',
#  'int-01-33611.dat',
#  'int-01-33621.dat',
#  'int-01-33631.dat',
#  'int-01-33641.dat',
#  'int-01-33651.dat',
#  'int-01-33661.dat',
#  'int-01-33671.dat',
#  'int-01-33681.dat',
#  'int-01-33691.dat',
#  'int-01-33701.dat',
#  'int-01-33711.dat',
#  'int-01-33721.dat',
#  'int-01-33731.dat',
#  'int-01-33741.dat',
# ...

# %%
data = pd.read_csv(file, sep='\s+').set_index('nodenumber')
data
# Out:
#             x-coordinate  y-coordinate  z-coordinate      pressure  \
# nodenumber
# 1              -0.042275      0.096415        -0.046   87865.10938
# 2              -0.041701      0.096666        -0.046   87871.71875
# 3              -0.041127      0.096918        -0.046   87877.08594
# 4              -0.040551      0.097164        -0.046   87881.48438
# 5              -0.039969      0.097397        -0.046   87884.63281
# 6              -0.039388      0.097630        -0.046   87887.76562
# 7              -0.038806      0.097863        -0.046   87889.84375
# 8              -0.038225      0.098096        -0.046   87891.32031
# 9              -0.037643      0.098329        -0.046   87892.57812
# 10             -0.037055      0.098545        -0.046   87894.35156
# 11             -0.036466      0.098759        -0.046   87896.41406
# 12             -0.035878      0.098974        -0.046   87897.77344
# 13             -0.035289      0.099188        -0.046   87898.35156
# ...

# %%
ts_vort_mag = pd.DataFrame()
for file in filelist:
    data = pd.read_csv(file, sep='\s+').set_index('nodenumber')
    data.columns = data.columns.str.strip()
    ts_vort_mag[file] = data['vorticity-mag']
    ts_vort_mag[file] = avg_vort_mag['vorticity-mag'] - ts_vort_mag[file]
ts_vort_mag
# Out:
#             int-01-33321.dat  int-01-33331.dat  int-01-33341.dat  \
# nodenumber
# 1                   1.639614          7.141552          7.451168
# 2                   3.057212          4.805991          4.604392
# 3                   4.960304          2.617943          1.525612
# 4                   5.790930          4.179251          1.201636
# 5                   5.105417          6.056925          3.174692
# 6                   3.710017          6.135065          5.004740
# 7                   1.583305          6.250099          5.524772
# 8                  -1.397694          4.913906          6.649959
# 9                  -1.747704          1.707893          5.861641
# 10                  0.950511         -0.051473          3.969523
# 11                  4.206896          0.569232          1.601458
# 12                  5.343700          4.532345         -0.270786
# 13                  2.924191          7.578945          2.398236
# ...

# %%
ts_vort_mag.to_csv('vort_ddes-int-01.dat', sep=',')

# %%
os.chdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-01')
batch_data = dd.read_csv('*.dat', delimiter=r"\s+", decimal='.', usecols=['nodenumber', 'vorticity-mag'])
avg_vort_mag = pd.DataFrame(batch_data.groupby('nodenumber').mean().compute())
filelist = sorted(os.listdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-01'))
ts_vort_mag = pd.DataFrame()
for file in filelist:
    data = pd.read_csv(file, sep='\s+').set_index('nodenumber')
    data.columns = data.columns.str.strip()
    ts_vort_mag[file] = data['vorticity-mag']
    ts_vort_mag[file] = avg_vort_mag['vorticity-mag'] - ts_vort_mag[file]
os.chdir(path_ddes)
ts_vort_mag.to_csv('vort_ddes-int-01.dat', sep=',')

# %%
os.chdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-02')
batch_data = dd.read_csv('*.dat', delimiter=r"\s+", decimal='.', usecols=['nodenumber', 'vorticity-mag'])
avg_vort_mag = pd.DataFrame(batch_data.groupby('nodenumber').mean().compute())
filelist = sorted(os.listdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-02'))
ts_vort_mag = pd.DataFrame()
for file in filelist:
    data = pd.read_csv(file, sep='\s+').set_index('nodenumber')
    data.columns = data.columns.str.strip()
    ts_vort_mag[file] = data['vorticity-mag']
    ts_vort_mag[file] = avg_vort_mag['vorticity-mag'] - ts_vort_mag[file]
os.chdir(path_ddes)
ts_vort_mag.to_csv('vort_ddes-int-02.dat', sep=',')

# %%
os.chdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-03')
batch_data = dd.read_csv('*.dat', delimiter=r"\s+", decimal='.', usecols=['nodenumber', 'vorticity-mag'])
avg_vort_mag = pd.DataFrame(batch_data.groupby('nodenumber').mean().compute())
filelist = sorted(os.listdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-03'))
ts_vort_mag = pd.DataFrame()
for file in filelist:
    data = pd.read_csv(file, sep='\s+').set_index('nodenumber')
    data.columns = data.columns.str.strip()
    ts_vort_mag[file] = data['vorticity-mag']
    ts_vort_mag[file] = avg_vort_mag['vorticity-mag'] - ts_vort_mag[file]
os.chdir(path_ddes)
ts_vort_mag.to_csv('vort_ddes-int-03.dat', sep=',')

# %%
os.chdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-04')
batch_data = dd.read_csv('*.dat', delimiter=r"\s+", decimal='.', usecols=['nodenumber', 'vorticity-mag'])
avg_vort_mag = pd.DataFrame(batch_data.groupby('nodenumber').mean().compute())
filelist = sorted(os.listdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-04'))
ts_vort_mag = pd.DataFrame()
for file in filelist:
    data = pd.read_csv(file, sep='\s+').set_index('nodenumber')
    data.columns = data.columns.str.strip()
    ts_vort_mag[file] = data['vorticity-mag']
    ts_vort_mag[file] = avg_vort_mag['vorticity-mag'] - ts_vort_mag[file]
os.chdir(path_ddes)
ts_vort_mag.to_csv('vort_ddes-int-04.dat', sep=',')

# %%
os.chdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-05')
batch_data = dd.read_csv('*.dat', delimiter=r"\s+", decimal='.', usecols=['nodenumber', 'vorticity-mag'])
avg_vort_mag = pd.DataFrame(batch_data.groupby('nodenumber').mean().compute())
filelist = sorted(os.listdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-05'))
ts_vort_mag = pd.DataFrame()
for file in filelist:
    data = pd.read_csv(file, sep='\s+').set_index('nodenumber')
    data.columns = data.columns.str.strip()
    ts_vort_mag[file] = data['vorticity-mag']
    ts_vort_mag[file] = avg_vort_mag['vorticity-mag'] - ts_vort_mag[file]
os.chdir(path_ddes)
ts_vort_mag.to_csv('vort_ddes-int-05.dat', sep=',')

# %%
os.chdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-07')
batch_data = dd.read_csv('*.dat', delimiter=r"\s+", decimal='.', usecols=['nodenumber', 'vorticity-mag'])
avg_vort_mag = pd.DataFrame(batch_data.groupby('nodenumber').mean().compute())
filelist = sorted(os.listdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-07'))
ts_vort_mag = pd.DataFrame()
for file in filelist:
    data = pd.read_csv(file, sep='\s+').set_index('nodenumber')
    data.columns = data.columns.str.strip()
    ts_vort_mag[file] = data['vorticity-mag']
    ts_vort_mag[file] = avg_vort_mag['vorticity-mag'] - ts_vort_mag[file]
os.chdir(path_ddes)
ts_vort_mag.to_csv('vort_ddes-int-07.dat', sep=',')

# %%
os.chdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-08')
batch_data = dd.read_csv('*.dat', delimiter=r"\s+", decimal='.', usecols=['nodenumber', 'vorticity-mag'])
avg_vort_mag = pd.DataFrame(batch_data.groupby('nodenumber').mean().compute())
filelist = sorted(os.listdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-08'))
ts_vort_mag = pd.DataFrame()
for file in filelist:
    data = pd.read_csv(file, sep='\s+').set_index('nodenumber')
    data.columns = data.columns.str.strip()
    ts_vort_mag[file] = data['vorticity-mag']
    ts_vort_mag[file] = avg_vort_mag['vorticity-mag'] - ts_vort_mag[file]
os.chdir(path_ddes)
ts_vort_mag.to_csv('vort_ddes-int-08.dat', sep=',')

# %%
os.chdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-09')
batch_data = dd.read_csv('*.dat', delimiter=r"\s+", decimal='.', usecols=['nodenumber', 'vorticity-mag'])
avg_vort_mag = pd.DataFrame(batch_data.groupby('nodenumber').mean().compute())
filelist = sorted(os.listdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-09'))
ts_vort_mag = pd.DataFrame()
for file in filelist:
    data = pd.read_csv(file, sep='\s+').set_index('nodenumber')
    data.columns = data.columns.str.strip()
    ts_vort_mag[file] = data['vorticity-mag']
    ts_vort_mag[file] = avg_vort_mag['vorticity-mag'] - ts_vort_mag[file]
os.chdir(path_ddes)
ts_vort_mag.to_csv('vort_ddes-int-09.dat', sep=',')

# %%
os.chdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-10')
batch_data = dd.read_csv('*.dat', delimiter=r"\s+", decimal='.', usecols=['nodenumber', 'vorticity-mag'])
avg_vort_mag = pd.DataFrame(batch_data.groupby('nodenumber').mean().compute())
filelist = sorted(os.listdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-10'))
ts_vort_mag = pd.DataFrame()
for file in filelist:
    data = pd.read_csv(file, sep='\s+').set_index('nodenumber')
    data.columns = data.columns.str.strip()
    ts_vort_mag[file] = data['vorticity-mag']
    ts_vort_mag[file] = avg_vort_mag['vorticity-mag'] - ts_vort_mag[file]
os.chdir(path_ddes)
ts_vort_mag.to_csv('vort_ddes-int-10.dat', sep=',')

# %%
os.chdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-11')
batch_data = dd.read_csv('*.dat', delimiter=r"\s+", decimal='.', usecols=['nodenumber', 'vorticity-mag'])
avg_vort_mag = pd.DataFrame(batch_data.groupby('nodenumber').mean().compute())
filelist = sorted(os.listdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-11'))
ts_vort_mag = pd.DataFrame()
for file in filelist:
    data = pd.read_csv(file, sep='\s+').set_index('nodenumber')
    data.columns = data.columns.str.strip()
    ts_vort_mag[file] = data['vorticity-mag']
    ts_vort_mag[file] = avg_vort_mag['vorticity-mag'] - ts_vort_mag[file]
os.chdir(path_ddes)
ts_vort_mag.to_csv('vort_ddes-int-11.dat', sep=',')

# %%
os.chdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-12')
batch_data = dd.read_csv('*.dat', delimiter=r"\s+", decimal='.', usecols=['nodenumber', 'vorticity-mag'])
avg_vort_mag = pd.DataFrame(batch_data.groupby('nodenumber').mean().compute())
filelist = sorted(os.listdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-12'))
ts_vort_mag = pd.DataFrame()
for file in filelist:
    data = pd.read_csv(file, sep='\s+').set_index('nodenumber')
    data.columns = data.columns.str.strip()
    ts_vort_mag[file] = data['vorticity-mag']
    ts_vort_mag[file] = avg_vort_mag['vorticity-mag'] - ts_vort_mag[file]
os.chdir(path_ddes)
ts_vort_mag.to_csv('vort_ddes-int-12.dat', sep=',')

# %%
os.chdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-tip')
batch_data = dd.read_csv('*.dat', delimiter=r"\s+", decimal='.', usecols=['nodenumber', 'vorticity-mag'])
avg_vort_mag = pd.DataFrame(batch_data.groupby('nodenumber').mean().compute())
filelist = sorted(os.listdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/int-tip'))
ts_vort_mag = pd.DataFrame()
for file in filelist:
    data = pd.read_csv(file, sep='\s+').set_index('nodenumber')
    data.columns = data.columns.str.strip()
    ts_vort_mag[file] = data['vorticity-mag']
    ts_vort_mag[file] = avg_vort_mag['vorticity-mag'] - ts_vort_mag[file]
os.chdir(path_ddes)
ts_vort_mag.to_csv('vort_ddes-int-tip.dat', sep=',')

# %%
os.chdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/lead')
batch_data = dd.read_csv('*.dat', delimiter=r"\s+", decimal='.', usecols=['nodenumber', 'vorticity-mag'])
avg_vort_mag = pd.DataFrame(batch_data.groupby('nodenumber').mean().compute())
filelist = sorted(os.listdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/lead'))
ts_vort_mag = pd.DataFrame()
for file in filelist:
    data = pd.read_csv(file, sep='\s+').set_index('nodenumber')
    data.columns = data.columns.str.strip()
    ts_vort_mag[file] = data['vorticity-mag']
    ts_vort_mag[file] = avg_vort_mag['vorticity-mag'] - ts_vort_mag[file]
os.chdir(path_ddes)
ts_vort_mag.to_csv('vort_ddes-lead.dat', sep=',')

# %%
os.chdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/pside')
batch_data = dd.read_csv('*.dat', delimiter=r"\s+", decimal='.', usecols=['nodenumber', 'vorticity-mag'])
avg_vort_mag = pd.DataFrame(batch_data.groupby('nodenumber').mean().compute())
filelist = sorted(os.listdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/pside'))
ts_vort_mag = pd.DataFrame()
for file in filelist:
    data = pd.read_csv(file, sep='\s+').set_index('nodenumber')
    data.columns = data.columns.str.strip()
    ts_vort_mag[file] = data['vorticity-mag']
    ts_vort_mag[file] = avg_vort_mag['vorticity-mag'] - ts_vort_mag[file]
os.chdir(path_ddes)
ts_vort_mag.to_csv('vort_ddes-pside.dat', sep=',')

# %%
os.chdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/sside')
batch_data = dd.read_csv('*.dat', delimiter=r"\s+", decimal='.', usecols=['nodenumber', 'vorticity-mag'])
avg_vort_mag = pd.DataFrame(batch_data.groupby('nodenumber').mean().compute())
filelist = sorted(os.listdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/sside'))
ts_vort_mag = pd.DataFrame()
for file in filelist:
    data = pd.read_csv(file, sep='\s+').set_index('nodenumber')
    data.columns = data.columns.str.strip()
    ts_vort_mag[file] = data['vorticity-mag']
    ts_vort_mag[file] = avg_vort_mag['vorticity-mag'] - ts_vort_mag[file]
os.chdir(path_ddes)
ts_vort_mag.to_csv('vort_ddes-sside.dat', sep=',')

# %%
os.chdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/tip')
batch_data = dd.read_csv('*.dat', delimiter=r"\s+", decimal='.', usecols=['nodenumber', 'vorticity-mag'])
avg_vort_mag = pd.DataFrame(batch_data.groupby('nodenumber').mean().compute())
filelist = sorted(os.listdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/tip'))
ts_vort_mag = pd.DataFrame()
for file in filelist:
    data = pd.read_csv(file, sep='\s+').set_index('nodenumber')
    data.columns = data.columns.str.strip()
    ts_vort_mag[file] = data['vorticity-mag']
    ts_vort_mag[file] = avg_vort_mag['vorticity-mag'] - ts_vort_mag[file]
os.chdir(path_ddes)
ts_vort_mag.to_csv('vort_ddes-tip.dat', sep=',')

# %%
os.chdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/trail')
batch_data = dd.read_csv('*.dat', delimiter=r"\s+", decimal='.', usecols=['nodenumber', 'vorticity-mag'])
avg_vort_mag = pd.DataFrame(batch_data.groupby('nodenumber').mean().compute())
filelist = sorted(os.listdir('/media/picard/data/anaconda/JJs_PHD/15_results/flow-data/trail'))
ts_vort_mag = pd.DataFrame()
for file in filelist:
    data = pd.read_csv(file, sep='\s+').set_index('nodenumber')
    data.columns = data.columns.str.strip()
    ts_vort_mag[file] = data['vorticity-mag']
    ts_vort_mag[file] = avg_vort_mag['vorticity-mag'] - ts_vort_mag[file]
os.chdir(path_ddes)
ts_vort_mag.to_csv('vort_ddes-trail.dat', sep=',')
